# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from datetime import datetime

# %%
from config import weather_api_key

# %%
def latitudes(sample):
    latitudes= list(np.random.uniform(-90.000, 90.000, size= sample))

    return latitudes

def longitudes (sample):
    longitudes= list(np.random.uniform(-180.000, 180.000, size= sample))
    
    return longitudes

# %%
coordinates= zip(latitudes(5500),longitudes(5500))

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['kruisfontein',
#  'namibe',
#  'yulara',
#  'vardo',
#  'vaini',
#  'ravar',
#  'lagos',
#  'hilo',
#  'iqaluit',
#  'hobart',
#  'ponta do sol',
#  'belushya guba',
#  'kapaa',
#  'athabasca',
#  'gat',
#  'hermanus',
#  'rikitea',
#  'alofi',
#  'castro',
#  'punta arenas',
#  'pisco',
#  'morgan city',
#  'cape town',
#  'port lincoln',
#  'klaksvik',
#  'tasiilaq',
#  'port alfred',
#  'taolanaro',
#  'port elizabeth',
#  'katobu',
#  'ayna',
#  'marawi',
#  'saint-philippe',
#  'kirakira',
#  'severo-kurilsk',
#  'solnechnyy',
#  'santa cruz',
#  'bambanglipuro',
#  'avera',
#  'grand river south east',
#  'albany',
#  'bengkulu',
#  'mataura',
#  'nyurba',
#  'ribeira grande',
#  'olinda',
#  'ilulissat',
#  'fortuna',
#  'juneau',
#  'bethel',
#  'ushuaia',
#  'jamestown',
#  'sambava',
#  'busselton',
#  'airai',
#  'labuhan',
#  'mar del plata',
#  'tura',
#  'pemangkat',
#  'wulanhaote',
#  'fairbanks',
#  'uyuni',
#  'katsuura',
#  'rabo de peixe',
#  'biltine',
#  'paamiut',
#  'povenets',
#  'urumqi',
#  'disna',
#  'zaysan',
#  'nanortalik',
#  'victoria',
#  'illoqqortoormiut',
#  'matagami',
#  'crab hill',
#  'mehamn',
#  'siuri',
#  'kismayo',
#  'cabo san lucas',
#  'cidreira',
#  'brae',
#  'bandarbeyla',
#  'mettur',
#  'muisne',
#  'tiksi',
#  'dikson',
#  'bluff',
#  'rio branco',
#  'amderma',
#  'arraial do cabo',
#  'roald',
#  'sao filipe',
#  'lezajsk',
#  'pirgos',
#  'thompson',
#  'rawson',
#  'buala',
#  'puerto ayora',
#  'sergeyevka',
#  'muros',
#  'nizhneyansk',
#  'tabiauea',
#  'odesskoye',
#  'saskylakh',
#  'port blair',
#  'khatanga',
#  'ahipara',
#  'tuatapere',
#  'longyearbyen',
#  'puerto del rosario',
#  'krasnoselkup',
#  'mys shmidta',
#  'sokolo',
#  'sitka',
#  'panguna',
#  'uige',
#  'nouadhibou',
#  'geraldton',
#  'new norfolk',
#  'butaritari',
#  'karangasem',
#  'yellowknife',
#  'srednekolymsk',
#  'ojinaga',
#  'colac',
#  'samusu',
#  'banda aceh',
#  'margineni',
#  'alice',
#  'avarua',
#  'sataua',
#  'ostrovnoy',
#  'gondanglegi',
#  'port moresby',
#  'lebu',
#  'touros',
#  'santa rosa',
#  'dunedin',
#  'rundu',
#  'coihaique',
#  'phetchaburi',
#  'kazalinsk',
#  'coolum beach',
#  'kavieng',
#  'laguna',
#  'buin',
#  'nara',
#  'lavrentiya',
#  'tuy hoa',
#  'kannur',
#  'pangnirtung',
#  'broome',
#  'torbay',
#  'khandyga',
#  'harper',
#  'barrow',
#  'sentyabrskiy',
#  'atuona',
#  'bredasdorp',
#  'honningsvag',
#  'ramban',
#  'tsihombe',
#  'tucupita',
#  'christchurch',
#  'richmond',
#  'yar-sale',
#  'thai nguyen',
#  'pereslavl-zalesskiy',
#  'college',
#  'gorin',
#  'ubinskoye',
#  'bereda',
#  'babu',
#  'chokurdakh',
#  'karaton',
#  'boa vista',
#  'georgetown',
#  'nome',
#  'ponta delgada',
#  'limon',
#  'cururupu',
#  'berdigestyakh',
#  'puerto madryn',
#  'corinto',
#  'bambous virieux',
#  'piacabucu',
#  'bahia honda',
#  'plouzane',
#  'carnarvon',
#  'chuy',
#  'vestmannaeyjar',
#  'beloha',
#  'kemijarvi',
#  'east london',
#  'pundaguitan',
#  'nelson bay',
#  'hofn',
#  'hambantota',
#  'zhanaozen',
#  'pontes e lacerda',
#  'batagay-alyta',
#  'boddam',
#  'ust-koksa',
#  'attawapiskat',
#  'tuktoyaktuk',
#  'xichang',
#  'dali',
#  'watertown',
#  'honiara',
#  'qaqortoq',
#  'hamilton',
#  'el sauzal',
#  'provideniya',
#  'cherskiy',
#  'constantine',
#  'santa maria',
#  'otjimbingwe',
#  'bhikangaon',
#  'karaul',
#  'kodiak',
#  'wau',
#  'obala',
#  'hirara',
#  'bosaso',
#  'upernavik',
#  'miri',
#  'mount gambier',
#  'chilca',
#  'dobroye',
#  'ende',
#  'ulladulla',
#  'antofagasta',
#  'mahebourg',
#  'coquimbo',
#  'taltal',
#  'oyotun',
#  'acarau',
#  'warud',
#  'riviere-au-renard',
#  'san patricio',
#  'luang prabang',
#  'patrocinio',
#  'stare mesto',
#  'bathsheba',
#  'nuuk',
#  'narsipatnam',
#  'saint anthony',
#  'narsaq',
#  'saldanha',
#  'sola',
#  'mhlambanyatsi',
#  'shimizu',
#  'yurimaguas',
#  'poum',
#  'ranfurly',
#  'pemba',
#  'tranas',
#  'maceio',
#  'carutapera',
#  'norman wells',
#  'abrau-dyurso',
#  'blagoyevo',
#  'san quintin',
#  'huarmey',
#  'ixtapa',
#  'dingle',
#  'lahat',
#  'voskresenskoye',
#  'reinosa',
#  'ahuimanu',
#  'lazaro cardenas',
#  'eureka',
#  'canon city',
#  'baruun-urt',
#  'livadiya',
#  'lagoa',
#  'hithadhoo',
#  'kirovskiy',
#  'storforshei',
#  'taoudenni',
#  'koraput',
#  'burica',
#  'illapel',
#  'narimanov',
#  'tessalit',
#  'shache',
#  'kieta',
#  'bukachacha',
#  'edd',
#  'babanusah',
#  'beringovskiy',
#  'besskorbnaya',
#  'kargasok',
#  'kamenka',
#  'bairiki',
#  'superior',
#  'kijabe',
#  'payo',
#  'vacaville',
#  'nikolskoye',
#  'gulu',
#  'walvis bay',
#  'leningradskiy',
#  'alamos',
#  'grindavik',
#  'faanui',
#  'biskamzha',
#  'gotsu',
#  'rincon',
#  'barentsburg',
#  'ranong',
#  'varhaug',
#  'lubbock',
#  'qaanaaq',
#  'formosa do rio preto',
#  'chaihe',
#  'ciudad bolivar',
#  'dakar',
#  'posse',
#  'valparaiso',
#  'ontario',
#  'souillac',
#  'nago',
#  'naron',
#  'half moon bay',
#  'quechultenango',
#  'whitehorse',
#  'banatski karlovac',
#  'the valley',
#  'halifax',
#  'kulhudhuffushi',
#  'belyy yar',
#  'pangody',
#  'palanga',
#  'jalingo',
#  'phek',
#  'atar',
#  'chagda',
#  'tumannyy',
#  'seoul',
#  'pontalina',
#  'chiang klang',
#  'aklavik',
#  'polistena',
#  'padang',
#  'chapais',
#  'den helder',
#  'bualan',
#  'port augusta',
#  'yima',
#  'weligama',
#  'ballina',
#  'saint-augustin',
#  'okha',
#  'la grande',
#  'russell',
#  'wahpeton',
#  'porto nacional',
#  'envira',
#  'bendigo',
#  'kununurra',
#  'meulaboh',
#  'jambi',
#  'tual',
#  'mananara',
#  'luderitz',
#  'tilichiki',
#  'riyadh',
#  'rognan',
#  'vilhena',
#  'saurimo',
#  'mandiana',
#  'asau',
#  'mosquera',
#  'askiz',
#  'kananga',
#  'blind river',
#  'nadym',
#  'rangoon',
#  'ugoofaaru',
#  'solano',
#  'visby',
#  'pizarro',
#  'kahului',
#  'kaitangata',
#  'hilpoltstein',
#  'alugan',
#  'lae',
#  'manhuacu',
#  'saleaula',
#  'sukhobezvodnoye',
#  'pimentel',
#  'salinas',
#  'shubarkuduk',
#  'vila',
#  'deputatskiy',
#  'marzuq',
#  'barra do garcas',
#  'humaita',
#  'pochutla',
#  'bundaberg',
#  'korla',
#  'oparino',
#  'toulepleu',
#  'pevek',
#  'menongue',
#  'cockburn town',
#  'surt',
#  'champerico',
#  'san andres',
#  'camana',
#  'ayia galini',
#  'kamaishi',
#  'ryotsu',
#  'esperance',
#  'abu kamal',
#  'shenjiamen',
#  'jalu',
#  'beyneu',
#  'baoqing',
#  'tautira',
#  'rocha',
#  'galesong',
#  'ouadda',
#  'dawlatabad',
#  'asfi',
#  'colombia',
#  'vaitupu',
#  'bolungarvik',
#  'jos',
#  'barbar',
#  'bulungu',
#  'indija',
#  'orlik',
#  'zyryanka',
#  'redlands',
#  'umm lajj',
#  'moranbah',
#  'parry sound',
#  'vostok',
#  'tikhvin',
#  'avanigadda',
#  'margate',
#  'umzimvubu',
#  'codrington',
#  'constitucion',
#  'daru',
#  'kovdor',
#  'loandjili',
#  'chirnogeni',
#  'blonduos',
#  'ialibu',
#  'keuruu',
#  'lompoc',
#  'ancud',
#  'kamenskoye',
#  'zelenets',
#  'sompeta',
#  'saint george',
#  'jumla',
#  'kozhva',
#  'westport',
#  'port-de-paix',
#  'sechura',
#  'calceta',
#  'praia',
#  'sakaiminato',
#  'verkhnyaya inta',
#  'nanded',
#  'ovalle',
#  'morada nova',
#  'posevnaya',
#  'sturgis',
#  'presidencia roque saenz pena',
#  'port-gentil',
#  'tefe',
#  'benicarlo',
#  'kostomuksha',
#  'mount isa',
#  'cayenne',
#  'mandera',
#  'davila',
#  'rawannawi',
#  'severnoye',
#  'hazorasp',
#  'great falls',
#  'peleduy',
#  'bonavista',
#  'ust-tsilma',
#  'lewisporte',
#  'sadri',
#  'pokhara',
#  'kalmunai',
#  'ishinomaki',
#  'trapani',
#  'muncar',
#  'grimari',
#  'oyama',
#  'gacko',
#  'razole',
#  'high level',
#  'belaya gora',
#  'charters towers',
#  'oropendolas',
#  'hasaki',
#  'cham',
#  'omboue',
#  'berlevag',
#  'villa del rosario',
#  'gedo',
#  'merrill',
#  'mentok',
#  'uspenskaya',
#  'namatanai',
#  'felidhoo',
#  'flinders',
#  'curvelo',
#  'yinchuan',
#  'yining',
#  'kupang',
#  'coari',
#  'praya',
#  'sayat',
#  'ilinskiy',
#  'finsterwalde',
#  'emerald',
#  'te anau',
#  'yashkul',
#  'saint-pierre',
#  'dukat',
#  'teya',
#  'bossembele',
#  'matara',
#  'libertador general san martin',
#  'khani',
#  'kuruman',
#  'coos bay',
#  'impfondo',
#  'khalkhal',
#  'ketchikan',
#  'guerrero negro',
#  'lorengau',
#  'shimoda',
#  'robertsport',
#  'whitianga',
#  'peniche',
#  'henties bay',
#  'auki',
#  'ndele',
#  'nacala',
#  'whyalla',
#  'ballitoville',
#  'portland',
#  'russkaya polyana',
#  'huayucachi',
#  'sarab',
#  'kuche',
#  'mutsu',
#  'bujumbura',
#  'havelock',
#  'puerto ayacucho',
#  'hualmay',
#  'bilibino',
#  'nortelandia',
#  'bilma',
#  'swellendam',
#  'kalmar',
#  'tongchuan',
#  'northam',
#  'ustye',
#  'tahe',
#  'slupsk',
#  'sakakah',
#  'plettenberg bay',
#  'clyde river',
#  'smirnykh',
#  'paita',
#  'morros',
#  'ukiah',
#  'tabou',
#  'bedford',
#  'hobyo',
#  'madimba',
#  'general roca',
#  'shagonar',
#  'balakhta',
#  'talnakh',
#  'coahuayana',
#  'arlit',
#  'praxedis guerrero',
#  'bijie',
#  'yerbogachen',
#  'rio gallegos',
#  'santander',
#  'longonjo',
#  'dar es salaam',
#  'husavik',
#  'liverpool',
#  'parana',
#  'vao',
#  'kumsi',
#  'cap malheureux',
#  'dong hoi',
#  'halden',
#  'thessalon',
#  'fernandopolis',
#  'ostashkov',
#  'turukhansk',
#  'koumra',
#  'huaihua',
#  'sistranda',
#  'minudasht',
#  'samarai',
#  'kjollefjord',
#  'kropotkin',
#  'gizo',
#  'syamzha',
#  'znamenskoye',
#  'buraydah',
#  'arica',
#  'anadyr',
#  'aksu',
#  'tynda',
#  'pingliang',
#  'zykovo',
#  'launceston',
#  'sampit',
#  'bokspits',
#  'sijunjung',
#  'los llanos de aridane',
#  'san cristobal',
#  'sao joao da barra',
#  'garissa',
#  'ceres',
#  'talcahuano',
#  'wundanyi',
#  'opuwo',
#  'rosarito',
#  'haileybury',
#  'maanshan',
#  'kiunga',
#  'kilindoni',
#  'jasper',
#  'maykain',
#  'andenes',
#  'madang',
#  'ilhabela',
#  'houma',
#  'elban',
#  'manacapuru',
#  'hwange',
#  'naze',
#  'vila velha',
#  'faya',
#  'mbaiki',
#  'alwar',
#  'ondangwa',
#  'wenzhou',
#  'fort-shevchenko',
#  'aitape',
#  'tonantins',
#  'zharkent',
#  'muskegon',
#  'jawhar',
#  'umtata',
#  'yangjiang',
#  'xiaoweizhai',
#  'melfi',
#  'siniscola',
#  'umm durman',
#  'thinadhoo',
#  'areia branca',
#  'myitkyina',
#  'mitu',
#  'toktogul',
#  'laurel',
#  'kawambwa',
#  'igualada',
#  'wadi musa',
#  'marrakesh',
#  'boysun',
#  'tevaitoa',
#  'magadan',
#  'kailasahar',
#  'harsin',
#  'ekhabi',
#  'manakara',
#  'selam',
#  'dosso',
#  'shimanovsk',
#  'rafiganj',
#  'atasu',
#  'mogadishu',
#  'lata',
#  'olafsvik',
#  'campoverde',
#  'havoysund',
#  'moissala',
#  'kyren',
#  'kapoeta',
#  'candawaga',
#  'sabang',
#  'richards bay',
#  'sorvag',
#  'batagay',
#  'hoi an',
#  'maarianhamina',
#  'chimbote',
#  'toyooka',
#  'midland',
#  'atakpame',
#  'safranbolu',
#  'yamada',
#  'dire',
#  'bo',
#  'houston',
#  'polis',
#  'shchelyayur',
#  'nove hrady',
#  'oktyabrskoye',
#  'serik',
#  'qinhuangdao',
#  'shamgarh',
#  'satitoa',
#  'tootsi',
#  'barawe',
#  'krasnyy kut',
#  'mlonggo',
#  'amazar',
#  'darlawn',
#  'deep river',
#  'sioux lookout',
#  'bubaque',
#  'mayo',
#  'tecoanapa',
#  'ust-kamchatsk',
#  'adrar',
#  'nalut',
#  'san policarpo',
#  'talara',
#  'conakry',
#  'boguchany',
#  'gobabis',
#  'santa isabel do rio negro',
#  'mandvi',
#  'porto de moz',
#  'bulolo',
#  'natal',
#  'turan',
#  'kouroussa',
#  'manor',
#  'itoman',
#  'zhigansk',
#  'krasnyy tkach',
#  'puerto pinasco',
#  'svetlyy',
#  'tampakan',
#  'arani',
#  'puerto escondido',
#  'karratha',
#  'thanh hoa',
#  'malakal',
#  'hunza',
#  'caravelas',
#  'mecca',
#  'esperantina',
#  'malatya',
#  'coalinga',
#  'kondinskoye',
#  'hay river',
#  'boende',
#  'mujiayingzi',
#  'kipini',
#  'karauzyak',
#  'shelburne',
#  'cheuskiny',
#  'sai buri',
#  'palmer',
#  'elizabeth city',
#  'dubbo',
#  'kyshtovka',
#  'sabaudia',
#  'zheleznodorozhnyy',
#  'bam',
#  'jocoro',
#  'ripoll',
#  'altagracia de orituco',
#  'sorland',
#  'mrirt',
#  'naftah',
#  'ust-ordynskiy',
#  'dalby',
#  'arroyo',
#  'batouri',
#  'sangar',
#  'lobamba',
#  'passagem franca',
#  'pasighat',
#  'shenkursk',
#  'charlestown',
#  'mollendo',
#  'lasa',
#  'mariental',
#  'zhezkazgan',
#  'inirida',
#  'vila franca do campo',
#  'kirillov',
#  'aksay',
#  'viligili',
#  'san carlos de bariloche',
#  'dudinka',
#  'belmonte',
#  'inongo',
#  'songjianghe',
#  'marsh harbour',
#  'weirton',
#  'shushtar',
#  'lithakia',
#  'bolu',
#  'mamakan',
#  'cartagena',
#  'diego de almagro',
#  'pangai',
#  'carballo',
#  'skelleftea',
#  'abalak',
#  'ngunguru',
#  'olsztyn',
#  'limoges',
#  'ewa beach',
#  'gaur',
#  'upata',
#  'alpharetta',
#  'sesheke',
#  'verkhniy uslon',
#  'kosh-agach',
#  'saint-francois',
#  'aykhal',
#  'phalombe',
#  'ca mau',
#  'gilbues',
#  'zadar',
#  'gambela',
#  'gigmoto',
#  'pringsewu',
#  'misratah',
#  'concarneau',
#  'petropavlovka',
#  'gamba',
#  'ilo',
#  'dondo',
#  'ust-kuyga',
#  'durban',
#  'san carlos',
#  'palabuhanratu',
#  'balarampur',
#  'balabac',
#  'pilar',
#  'bontang',
#  'lao cai',
#  'estremoz',
#  'alice springs',
#  'anahuac',
#  'juegang',
#  'willowmore',
#  'alotau',
#  'biak',
#  'san rafael',
#  'pirai do sul',
#  'lerwick',
#  'yangambi',
#  'kaura namoda',
#  'kavaratti',
#  'vuktyl',
#  'churapcha',
#  'ambovombe',
#  'uwayl',
#  'miquelon',
#  'pitimbu',
#  'northport',
#  'koratla',
#  'kingman',
#  'yumen',
#  'isangel',
#  'syktyvkar',
#  'marcona',
#  'bolonchen',
#  'wajima',
#  'tarauaca',
#  'ribeira brava',
#  'canaries',
#  'kenai',
#  'yaan',
#  'broken hill',
#  'van buren',
#  'stevens point',
#  'gornopravdinsk',
#  'balgazyn',
#  'sobolevo',
#  'bocanda',
#  'susanino',
#  'port hedland',
#  'muroto',
#  'zaliztsi',
#  'thongwa',
#  'aflu',
#  'pombas',
#  'kathmandu',
#  'kijang',
#  'nicolas bravo',
#  'saint-hyacinthe',
#  'letka',
#  'masallatah',
#  'egvekinot',
#  'balikpapan',
#  'changji',
#  'torrevieja',
#  'rio grande',
#  'muzaffarabad',
#  'jatai',
#  'lucknow',
#  'wuwei',
#  'ambilobe',
#  'lolua',
#  'jember',
#  'kawalu',
#  'wilmington',
#  'mao',
#  'cabedelo',
#  'port hardy',
#  'moron',
#  'darnah',
#  'bucksport',
#  'yarmouth',
#  'karpogory',
#  'astoria',
#  'ornskoldsvik',
#  'mazatlan',
#  'prainha',
#  'kidal',
#  'yokadouma',
#  'krasnoyarsk-66',
#  'alenquer',
#  'waingapu',
#  'bose',
#  'atocha',
#  'freeport',
#  'najran',
#  'tapaua',
#  'vanimo',
#  'porto walter',
#  'black river',
#  'lokosovo',
#  'burgersdorp',
#  'hope mills',
#  'san buenaventura',
#  'sofiysk',
#  'sumbawa',
#  'farah',
#  'hami',
#  'waipawa',
#  'necochea',
#  'acapulco',
#  'graneros',
#  'caiaponia',
#  'yuty',
#  'carora',
#  'bestobe',
#  'huilong',
#  'maloshuyka',
#  'callaguip',
#  'higuey',
#  'huaraz',
#  'antalaha',
#  'todos santos',
#  'atherton',
#  'tieling',
#  'bambari',
#  'chapleau',
#  'aguimes',
#  'luganville',
#  'sisimiut',
#  'inuvik',
#  'sehithwa',
#  'rungata',
#  'montelimar',
#  'oktyabrskiy',
#  'eregli',
#  'goderich',
#  'san antonio',
#  'suarez',
#  'voznesenye',
#  'kisangani',
#  'tutoia',
#  'liku',
#  'tukrah',
#  'rimbey',
#  'nouakchott',
#  'socorro',
#  'havre-saint-pierre',
#  ...]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url= url + "&q=" + "castro"
city_weather= requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -50.01, 'lat': -24.79},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 70.5,
#   'feels_like': 68,
#   'temp_min': 70.5,
#   'temp_max': 70.5,
#   'pressure': 1017,
#   'humidity': 63,
#   'sea_level': 1017,
#   'grnd_level': 907},
#  'wind': {'speed': 8.55, 'deg': 331},
#  'clouds': {'all': 2},
#  'dt': 1592590431,
#  'sys': {'country': 'BR', 'sunrise': 1592561017, 'sunset': 1592599162},
#  'timezone': -10800,
#  'id': 3466704,
#  'name': 'Castro',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | yulara
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | ravar
# Processing Record 7 of Set 1 | lagos
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | athabasca
# Processing Record 15 of Set 1 | gat
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | alofi
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | morgan city
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | port lincoln
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | katobu
# Processing Record 31 of Set 1 | ayna
# Processing Record 32 of Set 1 | marawi
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | kirakira
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | solnechnyy
# Processing Record 37 of Set 1 | santa cruz
# Processing Record 38 of Set 1 | bambanglipuro
# Processing Record 39 of Set 1 | avera
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | nyurba
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | olinda
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | juneau
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | sambava
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | airai
# Processing Record 6 of Set 2 | labuhan
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | tura
# Processing Record 9 of Set 2 | pemangkat
# Processing Record 10 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | uyuni
# Processing Record 13 of Set 2 | katsuura
# Processing Record 14 of Set 2 | rabo de peixe
# Processing Record 15 of Set 2 | biltine
# Processing Record 16 of Set 2 | paamiut
# Processing Record 17 of Set 2 | povenets
# Processing Record 18 of Set 2 | urumqi
# Processing Record 19 of Set 2 | disna
# Processing Record 20 of Set 2 | zaysan
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | matagami
# Processing Record 25 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 26 of Set 2 | mehamn
# Processing Record 27 of Set 2 | siuri
# Processing Record 28 of Set 2 | kismayo
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | brae
# Processing Record 32 of Set 2 | bandarbeyla
# Processing Record 33 of Set 2 | mettur
# Processing Record 34 of Set 2 | muisne
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | rio branco
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | roald
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | lezajsk
# Processing Record 44 of Set 2 | pirgos
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | rawson
# Processing Record 47 of Set 2 | buala
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | sergeyevka
# Processing Record 50 of Set 2 | muros
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 3 | odesskoye
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | port blair
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | ahipara
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | puerto del rosario
# Processing Record 11 of Set 3 | krasnoselkup
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | sokolo
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | panguna
# Processing Record 16 of Set 3 | uige
# Processing Record 17 of Set 3 | nouadhibou
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | karangasem
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | srednekolymsk
# Processing Record 24 of Set 3 | ojinaga
# Processing Record 25 of Set 3 | colac
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | banda aceh
# Processing Record 28 of Set 3 | margineni
# Processing Record 29 of Set 3 | alice
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 3 | ostrovnoy
# Processing Record 33 of Set 3 | gondanglegi
# Processing Record 34 of Set 3 | port moresby
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | santa rosa
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | rundu
# Processing Record 40 of Set 3 | coihaique
# Processing Record 41 of Set 3 | phetchaburi
# Processing Record 42 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 3 | coolum beach
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | buin
# Processing Record 47 of Set 3 | nara
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | tuy hoa
# Processing Record 50 of Set 3 | kannur
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | broome
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | khandyga
# Processing Record 5 of Set 4 | harper
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | atuona
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | honningsvag
# Processing Record 11 of Set 4 | ramban
# Processing Record 12 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 4 | tucupita
# Processing Record 14 of Set 4 | christchurch
# Processing Record 15 of Set 4 | richmond
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | thai nguyen
# Processing Record 18 of Set 4 | pereslavl-zalesskiy
# Processing Record 19 of Set 4 | college
# Processing Record 20 of Set 4 | gorin
# Processing Record 21 of Set 4 | ubinskoye
# Processing Record 22 of Set 4 | bereda
# Processing Record 23 of Set 4 | babu
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | karaton
# Processing Record 26 of Set 4 | boa vista
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | ponta delgada
# Processing Record 30 of Set 4 | limon
# Processing Record 31 of Set 4 | cururupu
# Processing Record 32 of Set 4 | berdigestyakh
# Processing Record 33 of Set 4 | puerto madryn
# Processing Record 34 of Set 4 | corinto
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | piacabucu
# Processing Record 37 of Set 4 | bahia honda
# Processing Record 38 of Set 4 | plouzane
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | vestmannaeyjar
# Processing Record 42 of Set 4 | beloha
# Processing Record 43 of Set 4 | kemijarvi
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | pundaguitan
# Processing Record 46 of Set 4 | nelson bay
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | hambantota
# Processing Record 49 of Set 4 | zhanaozen
# Processing Record 50 of Set 4 | pontes e lacerda
# Processing Record 1 of Set 5 | batagay-alyta
# Processing Record 2 of Set 5 | boddam
# Processing Record 3 of Set 5 | ust-koksa
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | xichang
# Processing Record 7 of Set 5 | dali
# Processing Record 8 of Set 5 | watertown
# Processing Record 9 of Set 5 | honiara
# Processing Record 10 of Set 5 | qaqortoq
# Processing Record 11 of Set 5 | hamilton
# Processing Record 12 of Set 5 | el sauzal
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | constantine
# Processing Record 16 of Set 5 | santa maria
# Processing Record 17 of Set 5 | otjimbingwe
# Processing Record 18 of Set 5 | bhikangaon
# Processing Record 19 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 5 | kodiak
# Processing Record 21 of Set 5 | wau
# Processing Record 22 of Set 5 | obala
# Processing Record 23 of Set 5 | hirara
# Processing Record 24 of Set 5 | bosaso
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | miri
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | chilca
# Processing Record 29 of Set 5 | dobroye
# Processing Record 30 of Set 5 | ende
# Processing Record 31 of Set 5 | ulladulla
# Processing Record 32 of Set 5 | antofagasta
# Processing Record 33 of Set 5 | mahebourg
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | taltal
# Processing Record 36 of Set 5 | oyotun
# Processing Record 37 of Set 5 | acarau
# Processing Record 38 of Set 5 | warud
# Processing Record 39 of Set 5 | riviere-au-renard
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | luang prabang
# Processing Record 42 of Set 5 | patrocinio
# Processing Record 43 of Set 5 | stare mesto
# Processing Record 44 of Set 5 | bathsheba
# Processing Record 45 of Set 5 | nuuk
# Processing Record 46 of Set 5 | narsipatnam
# Processing Record 47 of Set 5 | saint anthony
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | sola
# Processing Record 1 of Set 6 | mhlambanyatsi
# Processing Record 2 of Set 6 | shimizu
# Processing Record 3 of Set 6 | yurimaguas
# Processing Record 4 of Set 6 | poum
# Processing Record 5 of Set 6 | ranfurly
# Processing Record 6 of Set 6 | pemba
# Processing Record 7 of Set 6 | tranas
# Processing Record 8 of Set 6 | maceio
# Processing Record 9 of Set 6 | carutapera
# Processing Record 10 of Set 6 | norman wells
# Processing Record 11 of Set 6 | abrau-dyurso
# Processing Record 12 of Set 6 | blagoyevo
# Processing Record 13 of Set 6 | san quintin
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | ixtapa
# Processing Record 16 of Set 6 | dingle
# Processing Record 17 of Set 6 | lahat
# Processing Record 18 of Set 6 | voskresenskoye
# Processing Record 19 of Set 6 | reinosa
# Processing Record 20 of Set 6 | ahuimanu
# Processing Record 21 of Set 6 | lazaro cardenas
# Processing Record 22 of Set 6 | eureka
# Processing Record 23 of Set 6 | canon city
# Processing Record 24 of Set 6 | baruun-urt
# Processing Record 25 of Set 6 | livadiya
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | hithadhoo
# Processing Record 28 of Set 6 | kirovskiy
# Processing Record 29 of Set 6 | storforshei
# Processing Record 30 of Set 6 | taoudenni
# Processing Record 31 of Set 6 | koraput
# Processing Record 32 of Set 6 | burica
# City not found. Skipping...
# Processing Record 33 of Set 6 | illapel
# Processing Record 34 of Set 6 | narimanov
# Processing Record 35 of Set 6 | tessalit
# Processing Record 36 of Set 6 | shache
# Processing Record 37 of Set 6 | kieta
# Processing Record 38 of Set 6 | bukachacha
# Processing Record 39 of Set 6 | edd
# Processing Record 40 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 6 | beringovskiy
# Processing Record 42 of Set 6 | besskorbnaya
# Processing Record 43 of Set 6 | kargasok
# Processing Record 44 of Set 6 | kamenka
# Processing Record 45 of Set 6 | bairiki
# Processing Record 46 of Set 6 | superior
# Processing Record 47 of Set 6 | kijabe
# Processing Record 48 of Set 6 | payo
# Processing Record 49 of Set 6 | vacaville
# Processing Record 50 of Set 6 | nikolskoye
# Processing Record 1 of Set 7 | gulu
# Processing Record 2 of Set 7 | walvis bay
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | alamos
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | biskamzha
# Processing Record 8 of Set 7 | gotsu
# Processing Record 9 of Set 7 | rincon
# Processing Record 10 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 7 | ranong
# Processing Record 12 of Set 7 | varhaug
# Processing Record 13 of Set 7 | lubbock
# Processing Record 14 of Set 7 | qaanaaq
# Processing Record 15 of Set 7 | formosa do rio preto
# Processing Record 16 of Set 7 | chaihe
# Processing Record 17 of Set 7 | ciudad bolivar
# Processing Record 18 of Set 7 | dakar
# Processing Record 19 of Set 7 | posse
# Processing Record 20 of Set 7 | valparaiso
# Processing Record 21 of Set 7 | ontario
# Processing Record 22 of Set 7 | souillac
# Processing Record 23 of Set 7 | nago
# Processing Record 24 of Set 7 | naron
# Processing Record 25 of Set 7 | half moon bay
# Processing Record 26 of Set 7 | quechultenango
# Processing Record 27 of Set 7 | whitehorse
# Processing Record 28 of Set 7 | banatski karlovac
# Processing Record 29 of Set 7 | the valley
# Processing Record 30 of Set 7 | halifax
# Processing Record 31 of Set 7 | kulhudhuffushi
# Processing Record 32 of Set 7 | belyy yar
# Processing Record 33 of Set 7 | pangody
# Processing Record 34 of Set 7 | palanga
# Processing Record 35 of Set 7 | jalingo
# Processing Record 36 of Set 7 | phek
# Processing Record 37 of Set 7 | atar
# Processing Record 38 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 7 | seoul
# Processing Record 41 of Set 7 | pontalina
# Processing Record 42 of Set 7 | chiang klang
# Processing Record 43 of Set 7 | aklavik
# Processing Record 44 of Set 7 | polistena
# Processing Record 45 of Set 7 | padang
# Processing Record 46 of Set 7 | chapais
# Processing Record 47 of Set 7 | den helder
# Processing Record 48 of Set 7 | bualan
# Processing Record 49 of Set 7 | port augusta
# Processing Record 50 of Set 7 | yima
# Processing Record 1 of Set 8 | weligama
# Processing Record 2 of Set 8 | ballina
# Processing Record 3 of Set 8 | saint-augustin
# Processing Record 4 of Set 8 | okha
# Processing Record 5 of Set 8 | la grande
# Processing Record 6 of Set 8 | russell
# Processing Record 7 of Set 8 | wahpeton
# Processing Record 8 of Set 8 | porto nacional
# Processing Record 9 of Set 8 | envira
# Processing Record 10 of Set 8 | bendigo
# Processing Record 11 of Set 8 | kununurra
# Processing Record 12 of Set 8 | meulaboh
# Processing Record 13 of Set 8 | jambi
# Processing Record 14 of Set 8 | tual
# Processing Record 15 of Set 8 | mananara
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | tilichiki
# Processing Record 18 of Set 8 | riyadh
# Processing Record 19 of Set 8 | rognan
# Processing Record 20 of Set 8 | vilhena
# Processing Record 21 of Set 8 | saurimo
# Processing Record 22 of Set 8 | mandiana
# Processing Record 23 of Set 8 | asau
# Processing Record 24 of Set 8 | mosquera
# Processing Record 25 of Set 8 | askiz
# Processing Record 26 of Set 8 | kananga
# Processing Record 27 of Set 8 | blind river
# Processing Record 28 of Set 8 | nadym
# Processing Record 29 of Set 8 | rangoon
# Processing Record 30 of Set 8 | ugoofaaru
# Processing Record 31 of Set 8 | solano
# Processing Record 32 of Set 8 | visby
# Processing Record 33 of Set 8 | pizarro
# Processing Record 34 of Set 8 | kahului
# Processing Record 35 of Set 8 | kaitangata
# Processing Record 36 of Set 8 | hilpoltstein
# Processing Record 37 of Set 8 | alugan
# Processing Record 38 of Set 8 | lae
# Processing Record 39 of Set 8 | manhuacu
# Processing Record 40 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 8 | sukhobezvodnoye
# Processing Record 42 of Set 8 | pimentel
# Processing Record 43 of Set 8 | salinas
# Processing Record 44 of Set 8 | shubarkuduk
# Processing Record 45 of Set 8 | vila
# Processing Record 46 of Set 8 | deputatskiy
# Processing Record 47 of Set 8 | marzuq
# Processing Record 48 of Set 8 | barra do garcas
# Processing Record 49 of Set 8 | humaita
# Processing Record 50 of Set 8 | pochutla
# Processing Record 1 of Set 9 | bundaberg
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | oparino
# Processing Record 4 of Set 9 | toulepleu
# City not found. Skipping...
# Processing Record 5 of Set 9 | pevek
# Processing Record 6 of Set 9 | menongue
# Processing Record 7 of Set 9 | cockburn town
# Processing Record 8 of Set 9 | surt
# Processing Record 9 of Set 9 | champerico
# Processing Record 10 of Set 9 | san andres
# Processing Record 11 of Set 9 | camana
# Processing Record 12 of Set 9 | ayia galini
# Processing Record 13 of Set 9 | kamaishi
# Processing Record 14 of Set 9 | ryotsu
# Processing Record 15 of Set 9 | esperance
# Processing Record 16 of Set 9 | abu kamal
# Processing Record 17 of Set 9 | shenjiamen
# Processing Record 18 of Set 9 | jalu
# Processing Record 19 of Set 9 | beyneu
# Processing Record 20 of Set 9 | baoqing
# Processing Record 21 of Set 9 | tautira
# Processing Record 22 of Set 9 | rocha
# Processing Record 23 of Set 9 | galesong
# Processing Record 24 of Set 9 | ouadda
# Processing Record 25 of Set 9 | dawlatabad
# Processing Record 26 of Set 9 | asfi
# Processing Record 27 of Set 9 | colombia
# Processing Record 28 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 9 | jos
# Processing Record 31 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 9 | bulungu
# Processing Record 33 of Set 9 | indija
# Processing Record 34 of Set 9 | orlik
# Processing Record 35 of Set 9 | zyryanka
# Processing Record 36 of Set 9 | redlands
# Processing Record 37 of Set 9 | umm lajj
# Processing Record 38 of Set 9 | moranbah
# Processing Record 39 of Set 9 | parry sound
# Processing Record 40 of Set 9 | vostok
# Processing Record 41 of Set 9 | tikhvin
# Processing Record 42 of Set 9 | avanigadda
# Processing Record 43 of Set 9 | margate
# Processing Record 44 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 9 | codrington
# Processing Record 46 of Set 9 | constitucion
# Processing Record 47 of Set 9 | daru
# Processing Record 48 of Set 9 | kovdor
# Processing Record 49 of Set 9 | loandjili
# Processing Record 50 of Set 9 | chirnogeni
# Processing Record 1 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 2 of Set 10 | ialibu
# Processing Record 3 of Set 10 | keuruu
# Processing Record 4 of Set 10 | lompoc
# Processing Record 5 of Set 10 | ancud
# Processing Record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | zelenets
# Processing Record 8 of Set 10 | sompeta
# Processing Record 9 of Set 10 | saint george
# Processing Record 10 of Set 10 | jumla
# Processing Record 11 of Set 10 | kozhva
# Processing Record 12 of Set 10 | westport
# Processing Record 13 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 14 of Set 10 | sechura
# Processing Record 15 of Set 10 | calceta
# Processing Record 16 of Set 10 | praia
# Processing Record 17 of Set 10 | sakaiminato
# Processing Record 18 of Set 10 | verkhnyaya inta
# Processing Record 19 of Set 10 | nanded
# City not found. Skipping...
# Processing Record 20 of Set 10 | ovalle
# Processing Record 21 of Set 10 | morada nova
# Processing Record 22 of Set 10 | posevnaya
# Processing Record 23 of Set 10 | sturgis
# Processing Record 24 of Set 10 | presidencia roque saenz pena
# Processing Record 25 of Set 10 | port-gentil
# Processing Record 26 of Set 10 | tefe
# Processing Record 27 of Set 10 | benicarlo
# Processing Record 28 of Set 10 | kostomuksha
# Processing Record 29 of Set 10 | mount isa
# Processing Record 30 of Set 10 | cayenne
# Processing Record 31 of Set 10 | mandera
# Processing Record 32 of Set 10 | davila
# Processing Record 33 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 10 | severnoye
# Processing Record 35 of Set 10 | hazorasp
# Processing Record 36 of Set 10 | great falls
# Processing Record 37 of Set 10 | peleduy
# Processing Record 38 of Set 10 | bonavista
# Processing Record 39 of Set 10 | ust-tsilma
# Processing Record 40 of Set 10 | lewisporte
# Processing Record 41 of Set 10 | sadri
# Processing Record 42 of Set 10 | pokhara
# Processing Record 43 of Set 10 | kalmunai
# Processing Record 44 of Set 10 | ishinomaki
# Processing Record 45 of Set 10 | trapani
# Processing Record 46 of Set 10 | muncar
# Processing Record 47 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 48 of Set 10 | oyama
# Processing Record 49 of Set 10 | gacko
# Processing Record 50 of Set 10 | razole
# Processing Record 1 of Set 11 | high level
# Processing Record 2 of Set 11 | belaya gora
# Processing Record 3 of Set 11 | charters towers
# Processing Record 4 of Set 11 | oropendolas
# Processing Record 5 of Set 11 | hasaki
# Processing Record 6 of Set 11 | cham
# Processing Record 7 of Set 11 | omboue
# Processing Record 8 of Set 11 | berlevag
# Processing Record 9 of Set 11 | villa del rosario
# Processing Record 10 of Set 11 | gedo
# Processing Record 11 of Set 11 | merrill
# Processing Record 12 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 11 | uspenskaya
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 11 | flinders
# Processing Record 17 of Set 11 | curvelo
# Processing Record 18 of Set 11 | yinchuan
# Processing Record 19 of Set 11 | yining
# Processing Record 20 of Set 11 | kupang
# Processing Record 21 of Set 11 | coari
# Processing Record 22 of Set 11 | praya
# Processing Record 23 of Set 11 | sayat
# Processing Record 24 of Set 11 | ilinskiy
# Processing Record 25 of Set 11 | finsterwalde
# Processing Record 26 of Set 11 | emerald
# Processing Record 27 of Set 11 | te anau
# Processing Record 28 of Set 11 | yashkul
# Processing Record 29 of Set 11 | saint-pierre
# Processing Record 30 of Set 11 | dukat
# Processing Record 31 of Set 11 | teya
# Processing Record 32 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 33 of Set 11 | matara
# Processing Record 34 of Set 11 | libertador general san martin
# Processing Record 35 of Set 11 | khani
# Processing Record 36 of Set 11 | kuruman
# Processing Record 37 of Set 11 | coos bay
# Processing Record 38 of Set 11 | impfondo
# Processing Record 39 of Set 11 | khalkhal
# Processing Record 40 of Set 11 | ketchikan
# Processing Record 41 of Set 11 | guerrero negro
# Processing Record 42 of Set 11 | lorengau
# Processing Record 43 of Set 11 | shimoda
# Processing Record 44 of Set 11 | robertsport
# Processing Record 45 of Set 11 | whitianga
# Processing Record 46 of Set 11 | peniche
# Processing Record 47 of Set 11 | henties bay
# Processing Record 48 of Set 11 | auki
# Processing Record 49 of Set 11 | ndele
# Processing Record 50 of Set 11 | nacala
# Processing Record 1 of Set 12 | whyalla
# Processing Record 2 of Set 12 | ballitoville
# Processing Record 3 of Set 12 | portland
# Processing Record 4 of Set 12 | russkaya polyana
# Processing Record 5 of Set 12 | huayucachi
# Processing Record 6 of Set 12 | sarab
# Processing Record 7 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 12 | mutsu
# Processing Record 9 of Set 12 | bujumbura
# Processing Record 10 of Set 12 | havelock
# Processing Record 11 of Set 12 | puerto ayacucho
# Processing Record 12 of Set 12 | hualmay
# Processing Record 13 of Set 12 | bilibino
# Processing Record 14 of Set 12 | nortelandia
# Processing Record 15 of Set 12 | bilma
# Processing Record 16 of Set 12 | swellendam
# Processing Record 17 of Set 12 | kalmar
# Processing Record 18 of Set 12 | tongchuan
# Processing Record 19 of Set 12 | northam
# Processing Record 20 of Set 12 | ustye
# Processing Record 21 of Set 12 | tahe
# Processing Record 22 of Set 12 | slupsk
# Processing Record 23 of Set 12 | sakakah
# Processing Record 24 of Set 12 | plettenberg bay
# Processing Record 25 of Set 12 | clyde river
# Processing Record 26 of Set 12 | smirnykh
# Processing Record 27 of Set 12 | paita
# Processing Record 28 of Set 12 | morros
# Processing Record 29 of Set 12 | ukiah
# Processing Record 30 of Set 12 | tabou
# Processing Record 31 of Set 12 | bedford
# Processing Record 32 of Set 12 | hobyo
# Processing Record 33 of Set 12 | madimba
# Processing Record 34 of Set 12 | general roca
# Processing Record 35 of Set 12 | shagonar
# Processing Record 36 of Set 12 | balakhta
# Processing Record 37 of Set 12 | talnakh
# Processing Record 38 of Set 12 | coahuayana
# Processing Record 39 of Set 12 | arlit
# Processing Record 40 of Set 12 | praxedis guerrero
# Processing Record 41 of Set 12 | bijie
# Processing Record 42 of Set 12 | yerbogachen
# Processing Record 43 of Set 12 | rio gallegos
# Processing Record 44 of Set 12 | santander
# Processing Record 45 of Set 12 | longonjo
# Processing Record 46 of Set 12 | dar es salaam
# Processing Record 47 of Set 12 | husavik
# Processing Record 48 of Set 12 | liverpool
# Processing Record 49 of Set 12 | parana
# Processing Record 50 of Set 12 | vao
# Processing Record 1 of Set 13 | kumsi
# Processing Record 2 of Set 13 | cap malheureux
# Processing Record 3 of Set 13 | dong hoi
# Processing Record 4 of Set 13 | halden
# Processing Record 5 of Set 13 | thessalon
# Processing Record 6 of Set 13 | fernandopolis
# Processing Record 7 of Set 13 | ostashkov
# Processing Record 8 of Set 13 | turukhansk
# Processing Record 9 of Set 13 | koumra
# Processing Record 10 of Set 13 | huaihua
# Processing Record 11 of Set 13 | sistranda
# Processing Record 12 of Set 13 | minudasht
# Processing Record 13 of Set 13 | samarai
# Processing Record 14 of Set 13 | kjollefjord
# Processing Record 15 of Set 13 | kropotkin
# Processing Record 16 of Set 13 | gizo
# Processing Record 17 of Set 13 | syamzha
# Processing Record 18 of Set 13 | znamenskoye
# Processing Record 19 of Set 13 | buraydah
# Processing Record 20 of Set 13 | arica
# Processing Record 21 of Set 13 | anadyr
# Processing Record 22 of Set 13 | aksu
# Processing Record 23 of Set 13 | tynda
# Processing Record 24 of Set 13 | pingliang
# Processing Record 25 of Set 13 | zykovo
# Processing Record 26 of Set 13 | launceston
# Processing Record 27 of Set 13 | sampit
# Processing Record 28 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 13 | sijunjung
# Processing Record 30 of Set 13 | los llanos de aridane
# Processing Record 31 of Set 13 | san cristobal
# Processing Record 32 of Set 13 | sao joao da barra
# Processing Record 33 of Set 13 | garissa
# Processing Record 34 of Set 13 | ceres
# Processing Record 35 of Set 13 | talcahuano
# Processing Record 36 of Set 13 | wundanyi
# Processing Record 37 of Set 13 | opuwo
# Processing Record 38 of Set 13 | rosarito
# Processing Record 39 of Set 13 | haileybury
# Processing Record 40 of Set 13 | maanshan
# Processing Record 41 of Set 13 | kiunga
# Processing Record 42 of Set 13 | kilindoni
# Processing Record 43 of Set 13 | jasper
# Processing Record 44 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 45 of Set 13 | andenes
# Processing Record 46 of Set 13 | madang
# Processing Record 47 of Set 13 | ilhabela
# Processing Record 48 of Set 13 | houma
# Processing Record 49 of Set 13 | elban
# Processing Record 50 of Set 13 | manacapuru
# Processing Record 1 of Set 14 | hwange
# Processing Record 2 of Set 14 | naze
# Processing Record 3 of Set 14 | vila velha
# Processing Record 4 of Set 14 | faya
# Processing Record 5 of Set 14 | mbaiki
# Processing Record 6 of Set 14 | alwar
# Processing Record 7 of Set 14 | ondangwa
# Processing Record 8 of Set 14 | wenzhou
# Processing Record 9 of Set 14 | fort-shevchenko
# Processing Record 10 of Set 14 | aitape
# Processing Record 11 of Set 14 | tonantins
# Processing Record 12 of Set 14 | zharkent
# Processing Record 13 of Set 14 | muskegon
# Processing Record 14 of Set 14 | jawhar
# Processing Record 15 of Set 14 | umtata
# Processing Record 16 of Set 14 | yangjiang
# Processing Record 17 of Set 14 | xiaoweizhai
# Processing Record 18 of Set 14 | melfi
# Processing Record 19 of Set 14 | siniscola
# Processing Record 20 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 14 | thinadhoo
# Processing Record 22 of Set 14 | areia branca
# Processing Record 23 of Set 14 | myitkyina
# Processing Record 24 of Set 14 | mitu
# Processing Record 25 of Set 14 | toktogul
# Processing Record 26 of Set 14 | laurel
# Processing Record 27 of Set 14 | kawambwa
# Processing Record 28 of Set 14 | igualada
# Processing Record 29 of Set 14 | wadi musa
# Processing Record 30 of Set 14 | marrakesh
# Processing Record 31 of Set 14 | boysun
# Processing Record 32 of Set 14 | tevaitoa
# Processing Record 33 of Set 14 | magadan
# Processing Record 34 of Set 14 | kailasahar
# City not found. Skipping...
# Processing Record 35 of Set 14 | harsin
# Processing Record 36 of Set 14 | ekhabi
# Processing Record 37 of Set 14 | manakara
# Processing Record 38 of Set 14 | selam
# Processing Record 39 of Set 14 | dosso
# Processing Record 40 of Set 14 | shimanovsk
# Processing Record 41 of Set 14 | rafiganj
# Processing Record 42 of Set 14 | atasu
# Processing Record 43 of Set 14 | mogadishu
# Processing Record 44 of Set 14 | lata
# Processing Record 45 of Set 14 | olafsvik
# Processing Record 46 of Set 14 | campoverde
# Processing Record 47 of Set 14 | havoysund
# Processing Record 48 of Set 14 | moissala
# Processing Record 49 of Set 14 | kyren
# Processing Record 50 of Set 14 | kapoeta
# Processing Record 1 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 2 of Set 15 | sabang
# Processing Record 3 of Set 15 | richards bay
# Processing Record 4 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 15 | batagay
# Processing Record 6 of Set 15 | hoi an
# Processing Record 7 of Set 15 | maarianhamina
# Processing Record 8 of Set 15 | chimbote
# Processing Record 9 of Set 15 | toyooka
# Processing Record 10 of Set 15 | midland
# Processing Record 11 of Set 15 | atakpame
# Processing Record 12 of Set 15 | safranbolu
# Processing Record 13 of Set 15 | yamada
# Processing Record 14 of Set 15 | dire
# Processing Record 15 of Set 15 | bo
# City not found. Skipping...
# Processing Record 16 of Set 15 | houston
# Processing Record 17 of Set 15 | polis
# Processing Record 18 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 19 of Set 15 | nove hrady
# Processing Record 20 of Set 15 | oktyabrskoye
# Processing Record 21 of Set 15 | serik
# Processing Record 22 of Set 15 | qinhuangdao
# Processing Record 23 of Set 15 | shamgarh
# Processing Record 24 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 15 | tootsi
# Processing Record 26 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 15 | krasnyy kut
# Processing Record 28 of Set 15 | mlonggo
# Processing Record 29 of Set 15 | amazar
# Processing Record 30 of Set 15 | darlawn
# Processing Record 31 of Set 15 | deep river
# Processing Record 32 of Set 15 | sioux lookout
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | mayo
# Processing Record 35 of Set 15 | tecoanapa
# Processing Record 36 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 15 | adrar
# Processing Record 38 of Set 15 | nalut
# Processing Record 39 of Set 15 | san policarpo
# Processing Record 40 of Set 15 | talara
# Processing Record 41 of Set 15 | conakry
# Processing Record 42 of Set 15 | boguchany
# Processing Record 43 of Set 15 | gobabis
# Processing Record 44 of Set 15 | santa isabel do rio negro
# Processing Record 45 of Set 15 | mandvi
# Processing Record 46 of Set 15 | porto de moz
# Processing Record 47 of Set 15 | bulolo
# Processing Record 48 of Set 15 | natal
# Processing Record 49 of Set 15 | turan
# Processing Record 50 of Set 15 | kouroussa
# Processing Record 1 of Set 16 | manor
# Processing Record 2 of Set 16 | itoman
# Processing Record 3 of Set 16 | zhigansk
# Processing Record 4 of Set 16 | krasnyy tkach
# Processing Record 5 of Set 16 | puerto pinasco
# City not found. Skipping...
# Processing Record 6 of Set 16 | svetlyy
# Processing Record 7 of Set 16 | tampakan
# Processing Record 8 of Set 16 | arani
# Processing Record 9 of Set 16 | puerto escondido
# Processing Record 10 of Set 16 | karratha
# Processing Record 11 of Set 16 | thanh hoa
# Processing Record 12 of Set 16 | malakal
# Processing Record 13 of Set 16 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 16 | caravelas
# Processing Record 15 of Set 16 | mecca
# Processing Record 16 of Set 16 | esperantina
# Processing Record 17 of Set 16 | malatya
# Processing Record 18 of Set 16 | coalinga
# Processing Record 19 of Set 16 | kondinskoye
# Processing Record 20 of Set 16 | hay river
# Processing Record 21 of Set 16 | boende
# Processing Record 22 of Set 16 | mujiayingzi
# Processing Record 23 of Set 16 | kipini
# Processing Record 24 of Set 16 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 16 | shelburne
# Processing Record 26 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 16 | sai buri
# Processing Record 28 of Set 16 | palmer
# Processing Record 29 of Set 16 | elizabeth city
# Processing Record 30 of Set 16 | dubbo
# Processing Record 31 of Set 16 | kyshtovka
# Processing Record 32 of Set 16 | sabaudia
# Processing Record 33 of Set 16 | zheleznodorozhnyy
# Processing Record 34 of Set 16 | bam
# Processing Record 35 of Set 16 | jocoro
# Processing Record 36 of Set 16 | ripoll
# Processing Record 37 of Set 16 | altagracia de orituco
# Processing Record 38 of Set 16 | sorland
# Processing Record 39 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 16 | naftah
# City not found. Skipping...
# Processing Record 41 of Set 16 | ust-ordynskiy
# Processing Record 42 of Set 16 | dalby
# Processing Record 43 of Set 16 | arroyo
# Processing Record 44 of Set 16 | batouri
# Processing Record 45 of Set 16 | sangar
# Processing Record 46 of Set 16 | lobamba
# Processing Record 47 of Set 16 | passagem franca
# Processing Record 48 of Set 16 | pasighat
# Processing Record 49 of Set 16 | shenkursk
# Processing Record 50 of Set 16 | charlestown
# Processing Record 1 of Set 17 | mollendo
# Processing Record 2 of Set 17 | lasa
# Processing Record 3 of Set 17 | mariental
# Processing Record 4 of Set 17 | zhezkazgan
# Processing Record 5 of Set 17 | inirida
# Processing Record 6 of Set 17 | vila franca do campo
# Processing Record 7 of Set 17 | kirillov
# Processing Record 8 of Set 17 | aksay
# Processing Record 9 of Set 17 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 17 | san carlos de bariloche
# Processing Record 11 of Set 17 | dudinka
# Processing Record 12 of Set 17 | belmonte
# Processing Record 13 of Set 17 | inongo
# Processing Record 14 of Set 17 | songjianghe
# Processing Record 15 of Set 17 | marsh harbour
# Processing Record 16 of Set 17 | weirton
# Processing Record 17 of Set 17 | shushtar
# Processing Record 18 of Set 17 | lithakia
# Processing Record 19 of Set 17 | bolu
# Processing Record 20 of Set 17 | mamakan
# Processing Record 21 of Set 17 | cartagena
# Processing Record 22 of Set 17 | diego de almagro
# Processing Record 23 of Set 17 | pangai
# Processing Record 24 of Set 17 | carballo
# Processing Record 25 of Set 17 | skelleftea
# Processing Record 26 of Set 17 | abalak
# Processing Record 27 of Set 17 | ngunguru
# Processing Record 28 of Set 17 | olsztyn
# Processing Record 29 of Set 17 | limoges
# Processing Record 30 of Set 17 | ewa beach
# Processing Record 31 of Set 17 | gaur
# Processing Record 32 of Set 17 | upata
# Processing Record 33 of Set 17 | alpharetta
# Processing Record 34 of Set 17 | sesheke
# Processing Record 35 of Set 17 | verkhniy uslon
# Processing Record 36 of Set 17 | kosh-agach
# Processing Record 37 of Set 17 | saint-francois
# Processing Record 38 of Set 17 | aykhal
# Processing Record 39 of Set 17 | phalombe
# Processing Record 40 of Set 17 | ca mau
# Processing Record 41 of Set 17 | gilbues
# Processing Record 42 of Set 17 | zadar
# Processing Record 43 of Set 17 | gambela
# Processing Record 44 of Set 17 | gigmoto
# Processing Record 45 of Set 17 | pringsewu
# Processing Record 46 of Set 17 | misratah
# Processing Record 47 of Set 17 | concarneau
# Processing Record 48 of Set 17 | petropavlovka
# Processing Record 49 of Set 17 | gamba
# Processing Record 50 of Set 17 | ilo
# Processing Record 1 of Set 18 | dondo
# Processing Record 2 of Set 18 | ust-kuyga
# Processing Record 3 of Set 18 | durban
# Processing Record 4 of Set 18 | san carlos
# Processing Record 5 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 18 | balarampur
# Processing Record 7 of Set 18 | balabac
# Processing Record 8 of Set 18 | pilar
# Processing Record 9 of Set 18 | bontang
# Processing Record 10 of Set 18 | lao cai
# Processing Record 11 of Set 18 | estremoz
# Processing Record 12 of Set 18 | alice springs
# Processing Record 13 of Set 18 | anahuac
# Processing Record 14 of Set 18 | juegang
# Processing Record 15 of Set 18 | willowmore
# Processing Record 16 of Set 18 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 18 | biak
# Processing Record 18 of Set 18 | san rafael
# Processing Record 19 of Set 18 | pirai do sul
# Processing Record 20 of Set 18 | lerwick
# Processing Record 21 of Set 18 | yangambi
# Processing Record 22 of Set 18 | kaura namoda
# Processing Record 23 of Set 18 | kavaratti
# Processing Record 24 of Set 18 | vuktyl
# Processing Record 25 of Set 18 | churapcha
# Processing Record 26 of Set 18 | ambovombe
# Processing Record 27 of Set 18 | uwayl
# City not found. Skipping...
# Processing Record 28 of Set 18 | miquelon
# Processing Record 29 of Set 18 | pitimbu
# Processing Record 30 of Set 18 | northport
# Processing Record 31 of Set 18 | koratla
# Processing Record 32 of Set 18 | kingman
# Processing Record 33 of Set 18 | yumen
# Processing Record 34 of Set 18 | isangel
# Processing Record 35 of Set 18 | syktyvkar
# Processing Record 36 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 18 | bolonchen
# City not found. Skipping...
# Processing Record 38 of Set 18 | wajima
# Processing Record 39 of Set 18 | tarauaca
# Processing Record 40 of Set 18 | ribeira brava
# Processing Record 41 of Set 18 | canaries
# Processing Record 42 of Set 18 | kenai
# Processing Record 43 of Set 18 | yaan
# Processing Record 44 of Set 18 | broken hill
# Processing Record 45 of Set 18 | van buren
# Processing Record 46 of Set 18 | stevens point
# Processing Record 47 of Set 18 | gornopravdinsk
# Processing Record 48 of Set 18 | balgazyn
# Processing Record 49 of Set 18 | sobolevo
# Processing Record 50 of Set 18 | bocanda
# Processing Record 1 of Set 19 | susanino
# Processing Record 2 of Set 19 | port hedland
# Processing Record 3 of Set 19 | muroto
# Processing Record 4 of Set 19 | zaliztsi
# Processing Record 5 of Set 19 | thongwa
# Processing Record 6 of Set 19 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 19 | pombas
# Processing Record 8 of Set 19 | kathmandu
# Processing Record 9 of Set 19 | kijang
# Processing Record 10 of Set 19 | nicolas bravo
# Processing Record 11 of Set 19 | saint-hyacinthe
# Processing Record 12 of Set 19 | letka
# Processing Record 13 of Set 19 | masallatah
# Processing Record 14 of Set 19 | egvekinot
# Processing Record 15 of Set 19 | balikpapan
# Processing Record 16 of Set 19 | changji
# Processing Record 17 of Set 19 | torrevieja
# Processing Record 18 of Set 19 | rio grande
# Processing Record 19 of Set 19 | muzaffarabad
# Processing Record 20 of Set 19 | jatai
# Processing Record 21 of Set 19 | lucknow
# Processing Record 22 of Set 19 | wuwei
# Processing Record 23 of Set 19 | ambilobe
# Processing Record 24 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 19 | jember
# Processing Record 26 of Set 19 | kawalu
# Processing Record 27 of Set 19 | wilmington
# Processing Record 28 of Set 19 | mao
# Processing Record 29 of Set 19 | cabedelo
# Processing Record 30 of Set 19 | port hardy
# Processing Record 31 of Set 19 | moron
# Processing Record 32 of Set 19 | darnah
# Processing Record 33 of Set 19 | bucksport
# Processing Record 34 of Set 19 | yarmouth
# Processing Record 35 of Set 19 | karpogory
# Processing Record 36 of Set 19 | astoria
# Processing Record 37 of Set 19 | ornskoldsvik
# Processing Record 38 of Set 19 | mazatlan
# Processing Record 39 of Set 19 | prainha
# Processing Record 40 of Set 19 | kidal
# Processing Record 41 of Set 19 | yokadouma
# Processing Record 42 of Set 19 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 43 of Set 19 | alenquer
# Processing Record 44 of Set 19 | waingapu
# Processing Record 45 of Set 19 | bose
# Processing Record 46 of Set 19 | atocha
# Processing Record 47 of Set 19 | freeport
# Processing Record 48 of Set 19 | najran
# Processing Record 49 of Set 19 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 19 | vanimo
# Processing Record 1 of Set 20 | porto walter
# Processing Record 2 of Set 20 | black river
# Processing Record 3 of Set 20 | lokosovo
# Processing Record 4 of Set 20 | burgersdorp
# Processing Record 5 of Set 20 | hope mills
# Processing Record 6 of Set 20 | san buenaventura
# Processing Record 7 of Set 20 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 20 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 20 | farah
# Processing Record 10 of Set 20 | hami
# Processing Record 11 of Set 20 | waipawa
# Processing Record 12 of Set 20 | necochea
# Processing Record 13 of Set 20 | acapulco
# Processing Record 14 of Set 20 | graneros
# Processing Record 15 of Set 20 | caiaponia
# Processing Record 16 of Set 20 | yuty
# Processing Record 17 of Set 20 | carora
# Processing Record 18 of Set 20 | bestobe
# Processing Record 19 of Set 20 | huilong
# Processing Record 20 of Set 20 | maloshuyka
# City not found. Skipping...
# Processing Record 21 of Set 20 | callaguip
# Processing Record 22 of Set 20 | higuey
# City not found. Skipping...
# Processing Record 23 of Set 20 | huaraz
# Processing Record 24 of Set 20 | antalaha
# Processing Record 25 of Set 20 | todos santos
# Processing Record 26 of Set 20 | atherton
# Processing Record 27 of Set 20 | tieling
# Processing Record 28 of Set 20 | bambari
# Processing Record 29 of Set 20 | chapleau
# Processing Record 30 of Set 20 | aguimes
# Processing Record 31 of Set 20 | luganville
# Processing Record 32 of Set 20 | sisimiut
# Processing Record 33 of Set 20 | inuvik
# Processing Record 34 of Set 20 | sehithwa
# Processing Record 35 of Set 20 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 20 | montelimar
# Processing Record 37 of Set 20 | oktyabrskiy
# Processing Record 38 of Set 20 | eregli
# Processing Record 39 of Set 20 | goderich
# Processing Record 40 of Set 20 | san antonio
# Processing Record 41 of Set 20 | suarez
# Processing Record 42 of Set 20 | voznesenye
# Processing Record 43 of Set 20 | kisangani
# Processing Record 44 of Set 20 | tutoia
# Processing Record 45 of Set 20 | liku
# Processing Record 46 of Set 20 | tukrah
# Processing Record 47 of Set 20 | rimbey
# Processing Record 48 of Set 20 | nouakchott
# Processing Record 49 of Set 20 | socorro
# Processing Record 50 of Set 20 | havre-saint-pierre
# Processing Record 1 of Set 21 | ust-ishim
# Processing Record 2 of Set 21 | porkhov
# Processing Record 3 of Set 21 | pavlogradka
# Processing Record 4 of Set 21 | cathedral city
# Processing Record 5 of Set 21 | birjand
# Processing Record 6 of Set 21 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 21 | boyuibe
# Processing Record 8 of Set 21 | wembley
# Processing Record 9 of Set 21 | gasa
# Processing Record 10 of Set 21 | santo anastacio
# Processing Record 11 of Set 21 | esmeraldas
# Processing Record 12 of Set 21 | osa
# Processing Record 13 of Set 21 | zabaykalsk
# Processing Record 14 of Set 21 | marsa matruh
# Processing Record 15 of Set 21 | mwanza
# Processing Record 16 of Set 21 | sindor
# Processing Record 17 of Set 21 | wagga wagga
# Processing Record 18 of Set 21 | gazli
# Processing Record 19 of Set 21 | north bend
# Processing Record 20 of Set 21 | adra
# Processing Record 21 of Set 21 | jinchang
# Processing Record 22 of Set 21 | jiblah
# Processing Record 23 of Set 21 | banihal
# Processing Record 24 of Set 21 | mayahi
# Processing Record 25 of Set 21 | jacareacanga
# Processing Record 26 of Set 21 | ternate
# Processing Record 27 of Set 21 | bintulu
# Processing Record 28 of Set 21 | trincomalee
# Processing Record 29 of Set 21 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 21 | camacha
# Processing Record 31 of Set 21 | normandin
# Processing Record 32 of Set 21 | azimur
# City not found. Skipping...
# Processing Record 33 of Set 21 | yershov
# Processing Record 34 of Set 21 | soyo
# Processing Record 35 of Set 21 | nieuwpoort
# Processing Record 36 of Set 21 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 21 | nehe
# Processing Record 38 of Set 21 | canakkale
# Processing Record 39 of Set 21 | prince george
# Processing Record 40 of Set 21 | alexandria
# Processing Record 41 of Set 21 | kholtoson
# Processing Record 42 of Set 21 | laela
# Processing Record 43 of Set 21 | kendari
# Processing Record 44 of Set 21 | msanga
# Processing Record 45 of Set 21 | sa kaeo
# Processing Record 46 of Set 21 | salalah
# Processing Record 47 of Set 21 | eyl
# Processing Record 48 of Set 21 | buta
# Processing Record 49 of Set 21 | san rafael del sur
# Processing Record 50 of Set 21 | iralaya
# Processing Record 1 of Set 22 | llandrindod wells
# Processing Record 2 of Set 22 | vitim
# Processing Record 3 of Set 22 | naryan-mar
# Processing Record 4 of Set 22 | vangaindrano
# Processing Record 5 of Set 22 | hovd
# Processing Record 6 of Set 22 | sibolga
# Processing Record 7 of Set 22 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 22 | samandag
# Processing Record 9 of Set 22 | tambovka
# Processing Record 10 of Set 22 | dafeng
# Processing Record 11 of Set 22 | haines junction
# Processing Record 12 of Set 22 | kuznechnoye
# Processing Record 13 of Set 22 | lannion
# Processing Record 14 of Set 22 | hibbing
# Processing Record 15 of Set 22 | piedras
# Processing Record 16 of Set 22 | moindou
# Processing Record 17 of Set 22 | krasnokamensk
# Processing Record 18 of Set 22 | leh
# Processing Record 19 of Set 22 | boa esperanca
# Processing Record 20 of Set 22 | milkovo
# Processing Record 21 of Set 22 | nizhniy baskunchak
# Processing Record 22 of Set 22 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 22 | araripina
# Processing Record 24 of Set 22 | tari
# Processing Record 25 of Set 22 | devonport
# Processing Record 26 of Set 22 | yabrud
# Processing Record 27 of Set 22 | sivas
# Processing Record 28 of Set 22 | imperia
# Processing Record 29 of Set 22 | alta floresta
# Processing Record 30 of Set 22 | brandon
# Processing Record 31 of Set 22 | inhambane
# Processing Record 32 of Set 22 | ostersund
# Processing Record 33 of Set 22 | jabiru
# City not found. Skipping...
# Processing Record 34 of Set 22 | waddan
# Processing Record 35 of Set 22 | morondava
# Processing Record 36 of Set 22 | arman
# Processing Record 37 of Set 22 | ibra
# Processing Record 38 of Set 22 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 22 | tammisaari
# Processing Record 40 of Set 22 | hervey bay
# Processing Record 41 of Set 22 | bajil
# Processing Record 42 of Set 22 | santa lucia
# Processing Record 43 of Set 22 | placido de castro
# Processing Record 44 of Set 22 | beberibe
# Processing Record 45 of Set 22 | yatou
# Processing Record 46 of Set 22 | romny
# Processing Record 47 of Set 22 | haldibari
# Processing Record 48 of Set 22 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 22 | redwater
# ...
# Processing Record 25 of Set 24 | songkhla
# Processing Record 26 of Set 24 | amahai
# Processing Record 27 of Set 24 | koumac
# Processing Record 28 of Set 24 | chase
# Processing Record 29 of Set 24 | usoke
# Processing Record 30 of Set 24 | kui buri
# Processing Record 31 of Set 24 | dharchula
# Processing Record 32 of Set 24 | makakilo city
# Processing Record 33 of Set 24 | nishihara
# Processing Record 34 of Set 24 | borujan
# City not found. Skipping...
# Processing Record 35 of Set 24 | lawton
# Processing Record 36 of Set 24 | daokou
# Processing Record 37 of Set 24 | isla aguada
# Processing Record 38 of Set 24 | severnyy
# Processing Record 39 of Set 24 | devils lake
# Processing Record 40 of Set 24 | channel-port aux basques
# Processing Record 41 of Set 24 | corrente
# Processing Record 42 of Set 24 | saquarema
# Processing Record 43 of Set 24 | tulum
# Processing Record 44 of Set 24 | grand gaube
# Processing Record 45 of Set 24 | laredo
# Processing Record 46 of Set 24 | kargil
# Processing Record 47 of Set 24 | luanda
# Processing Record 48 of Set 24 | abha
# Processing Record 49 of Set 24 | anshun
# Processing Record 50 of Set 24 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 25 | banjar
# Processing Record 2 of Set 25 | lardos
# Processing Record 3 of Set 25 | catamarca
# Processing Record 4 of Set 25 | smithers
# Processing Record 5 of Set 25 | kandrian
# Processing Record 6 of Set 25 | karakol
# Processing Record 7 of Set 25 | jieshi
# Processing Record 8 of Set 25 | xai-xai
# Processing Record 9 of Set 25 | veraval
# Processing Record 10 of Set 25 | maldonado
# Processing Record 11 of Set 25 | chitrakonda
# Processing Record 12 of Set 25 | kharp
# Processing Record 13 of Set 25 | chifeng
# Processing Record 14 of Set 25 | saint-joseph
# Processing Record 15 of Set 25 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 25 | cuenca
# Processing Record 17 of Set 25 | ous
# Processing Record 18 of Set 25 | svetlogorsk
# Processing Record 19 of Set 25 | ayan
# Processing Record 20 of Set 25 | yei
# Processing Record 21 of Set 25 | kuzhorskaya
# Processing Record 22 of Set 25 | nurota
# Processing Record 23 of Set 25 | humberto de campos
# Processing Record 24 of Set 25 | vondrozo
# Processing Record 25 of Set 25 | teguise
# Processing Record 26 of Set 25 | umarkot
# Processing Record 27 of Set 25 | varkkallai
# Processing Record 28 of Set 25 | zeya
# Processing Record 29 of Set 25 | brasileia
# Processing Record 30 of Set 25 | yabelo
# Processing Record 31 of Set 25 | abu samrah
# Processing Record 32 of Set 25 | novochernorechenskiy
# Processing Record 33 of Set 25 | morris
# Processing Record 34 of Set 25 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 25 | itarema
# Processing Record 36 of Set 25 | jomalig
# City not found. Skipping...
# Processing Record 37 of Set 25 | safaga
# Processing Record 38 of Set 25 | joaima
# Processing Record 39 of Set 25 | pacasmayo
# Processing Record 40 of Set 25 | arua
# Processing Record 41 of Set 25 | verkhnyaya toyma
# Processing Record 42 of Set 25 | bantry
# Processing Record 43 of Set 25 | monrovia
# Processing Record 44 of Set 25 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 25 | budelsdorf
# Processing Record 46 of Set 25 | shumskiy
# Processing Record 47 of Set 25 | isla mujeres
# Processing Record 48 of Set 25 | tarko-sale
# Processing Record 49 of Set 25 | tres arroyos
# Processing Record 50 of Set 25 | mathathane
# Processing Record 1 of Set 26 | thio
# Processing Record 2 of Set 26 | mandurah
# Processing Record 3 of Set 26 | pahrump
# Processing Record 4 of Set 26 | pagudpud
# Processing Record 5 of Set 26 | grants
# Processing Record 6 of Set 26 | mangit
# Processing Record 7 of Set 26 | macheng
# Processing Record 8 of Set 26 | mirnyy
# Processing Record 9 of Set 26 | nur
# Processing Record 10 of Set 26 | machali
# Processing Record 11 of Set 26 | cizre
# Processing Record 12 of Set 26 | tovuz
# Processing Record 13 of Set 26 | gold coast
# Processing Record 14 of Set 26 | gimli
# Processing Record 15 of Set 26 | agen
# Processing Record 16 of Set 26 | klyuchi
# Processing Record 17 of Set 26 | cacoal
# Processing Record 18 of Set 26 | manokwari
# Processing Record 19 of Set 26 | sovetsk
# Processing Record 20 of Set 26 | cerrito
# Processing Record 21 of Set 26 | quatre cocos
# Processing Record 22 of Set 26 | ayagoz
# Processing Record 23 of Set 26 | kyzyl-suu
# Processing Record 24 of Set 26 | simao
# Processing Record 25 of Set 26 | penzance
# Processing Record 26 of Set 26 | atkinson
# Processing Record 27 of Set 26 | thunder bay
# Processing Record 28 of Set 26 | lianzhou
# Processing Record 29 of Set 26 | katherine
# Processing Record 30 of Set 26 | svetlaya
# Processing Record 31 of Set 26 | wolmaranstad
# City not found. Skipping...
# Processing Record 32 of Set 26 | awjilah
# Processing Record 33 of Set 26 | jerusalen
# Processing Record 34 of Set 26 | lima
# Processing Record 35 of Set 26 | jurilovca
# Processing Record 36 of Set 26 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 26 | kant
# Processing Record 38 of Set 26 | coracora
# Processing Record 39 of Set 26 | san jose
# Processing Record 40 of Set 26 | chumikan
# Processing Record 41 of Set 26 | tazovskiy
# Processing Record 42 of Set 26 | balsthal
# Processing Record 43 of Set 26 | roseburg
# Processing Record 44 of Set 26 | kudahuvadhoo
# Processing Record 45 of Set 26 | bernau
# Processing Record 46 of Set 26 | price
# Processing Record 47 of Set 26 | bondoukou
# Processing Record 48 of Set 26 | gornyy
# Processing Record 49 of Set 26 | moose factory
# Processing Record 50 of Set 26 | tamiahua
# Processing Record 1 of Set 27 | zholymbet
# Processing Record 2 of Set 27 | tolbazy
# Processing Record 3 of Set 27 | zapolyarnyy
# Processing Record 4 of Set 27 | nikki
# Processing Record 5 of Set 27 | kholmy
# Processing Record 6 of Set 27 | murray bridge
# Processing Record 7 of Set 27 | shingu
# Processing Record 8 of Set 27 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 27 | hit
# Processing Record 10 of Set 27 | kedgwick
# Processing Record 11 of Set 27 | nha trang
# Processing Record 12 of Set 27 | okhotsk
# Processing Record 13 of Set 27 | muzaffargarh
# Processing Record 14 of Set 27 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 27 | texarkana
# Processing Record 16 of Set 27 | la rioja
# Processing Record 17 of Set 27 | krasnomayskiy
# Processing Record 18 of Set 27 | abonnema
# Processing Record 19 of Set 27 | trinidad
# Processing Record 20 of Set 27 | vidin
# Processing Record 21 of Set 27 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 27 | anloga
# Processing Record 23 of Set 27 | conceicao do araguaia
# Processing Record 24 of Set 27 | kamina
# Processing Record 25 of Set 27 | one hundred mile house
# City not found. Skipping...
# Processing Record 26 of Set 27 | conceicao da barra
# Processing Record 27 of Set 27 | bingerville
# Processing Record 28 of Set 27 | teeli
# Processing Record 29 of Set 27 | uravakonda
# Processing Record 30 of Set 27 | volosovo
# Processing Record 31 of Set 27 | mahon
# Processing Record 32 of Set 27 | notre-dame-du-lac
# Processing Record 33 of Set 27 | nguru
# Processing Record 34 of Set 27 | celestun
# Processing Record 35 of Set 27 | nador
# Processing Record 36 of Set 27 | hauterive
# Processing Record 37 of Set 27 | taber
# Processing Record 38 of Set 27 | vigrestad
# Processing Record 39 of Set 27 | sipka
# City not found. Skipping...
# Processing Record 40 of Set 27 | mweka
# Processing Record 41 of Set 27 | tomatlan
# Processing Record 42 of Set 27 | quang ngai
# Processing Record 43 of Set 27 | nhulunbuy
# Processing Record 44 of Set 27 | punta gorda
# Processing Record 45 of Set 27 | tierra blanca
# Processing Record 46 of Set 27 | rapid valley
# Processing Record 47 of Set 27 | iberia
# Processing Record 48 of Set 27 | sukagawa
# Processing Record 49 of Set 27 | kaminoyama
# Processing Record 50 of Set 27 | ambunti
# Processing Record 1 of Set 28 | lac du bonnet
# Processing Record 2 of Set 28 | santuario
# Processing Record 3 of Set 28 | salisbury
# Processing Record 4 of Set 28 | saint-georges
# Processing Record 5 of Set 28 | wharton
# Processing Record 6 of Set 28 | pinili
# Processing Record 7 of Set 28 | kimberley
# Processing Record 8 of Set 28 | dwarka
# Processing Record 9 of Set 28 | qingdao
# Processing Record 10 of Set 28 | alagoinhas
# Processing Record 11 of Set 28 | linhares
# Processing Record 12 of Set 28 | manjacaze
# Processing Record 13 of Set 28 | manono
# Processing Record 14 of Set 28 | great yarmouth
# Processing Record 15 of Set 28 | front royal
# Processing Record 16 of Set 28 | nantucket
# Processing Record 17 of Set 28 | bennettsville
# Processing Record 18 of Set 28 | esik
# Processing Record 19 of Set 28 | campbellsville
# Processing Record 20 of Set 28 | seymchan
# Processing Record 21 of Set 28 | shenzhen
# Processing Record 22 of Set 28 | linden
# Processing Record 23 of Set 28 | mitsamiouli
# Processing Record 24 of Set 28 | dingwall
# Processing Record 25 of Set 28 | mildura
# Processing Record 26 of Set 28 | usinsk
# Processing Record 27 of Set 28 | a
# City not found. Skipping...
# Processing Record 28 of Set 28 | rodrigues alves
# Processing Record 29 of Set 28 | rockland
# Processing Record 30 of Set 28 | rutul
# Processing Record 31 of Set 28 | vera cruz
# Processing Record 32 of Set 28 | camacupa
# Processing Record 33 of Set 28 | evensk
# Processing Record 34 of Set 28 | donskoye
# Processing Record 35 of Set 28 | southbridge
# Processing Record 36 of Set 28 | sarankhola
# Processing Record 37 of Set 28 | medea
# Processing Record 38 of Set 28 | nanhyanga
# Processing Record 39 of Set 28 | dhidhdhoo
# Processing Record 40 of Set 28 | idar
# Processing Record 41 of Set 28 | bialogard
# Processing Record 42 of Set 28 | calama
# Processing Record 43 of Set 28 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 28 | khash
# Processing Record 45 of Set 28 | hermosillo
# Processing Record 46 of Set 28 | puerto lleras
# Processing Record 47 of Set 28 | sindou
# Processing Record 48 of Set 28 | tagusao
# Processing Record 49 of Set 28 | kericho
# Processing Record 50 of Set 28 | grand-santi
# Processing Record 1 of Set 29 | si sa ket
# Processing Record 2 of Set 29 | esmeralda
# Processing Record 3 of Set 29 | dumas
# Processing Record 4 of Set 29 | kaabong
# Processing Record 5 of Set 29 | la ronge
# Processing Record 6 of Set 29 | campbell river
# Processing Record 7 of Set 29 | mareeba
# Processing Record 8 of Set 29 | suntar
# Processing Record 9 of Set 29 | roma
# Processing Record 10 of Set 29 | la tuque
# Processing Record 11 of Set 29 | maniitsoq
# Processing Record 12 of Set 29 | sohag
# Processing Record 13 of Set 29 | mizdah
# Processing Record 14 of Set 29 | chippewa falls
# Processing Record 15 of Set 29 | malanje
# Processing Record 16 of Set 29 | barentu
# Processing Record 17 of Set 29 | angoram
# Processing Record 18 of Set 29 | nampula
# Processing Record 19 of Set 29 | tornio
# Processing Record 20 of Set 29 | fukue
# Processing Record 21 of Set 29 | farafangana
# Processing Record 22 of Set 29 | oranjemund
# Processing Record 23 of Set 29 | clonakilty
# Processing Record 24 of Set 29 | santa vitoria do palmar
# Processing Record 25 of Set 29 | dalgopol
# Processing Record 26 of Set 29 | peski
# Processing Record 27 of Set 29 | oudtshoorn
# Processing Record 28 of Set 29 | la paz
# Processing Record 29 of Set 29 | mandalgovi
# Processing Record 30 of Set 29 | muravlenko
# Processing Record 31 of Set 29 | bonthe
# Processing Record 32 of Set 29 | erzin
# Processing Record 33 of Set 29 | tunghsiao
# City not found. Skipping...
# Processing Record 34 of Set 29 | doha
# Processing Record 35 of Set 29 | teknaf
# Processing Record 36 of Set 29 | la baneza
# Processing Record 37 of Set 29 | anori
# Processing Record 38 of Set 29 | krasnaya gora
# Processing Record 39 of Set 29 | karpathos
# Processing Record 40 of Set 29 | urengoy
# Processing Record 41 of Set 29 | mahabad
# Processing Record 42 of Set 29 | mbanza-ngungu
# Processing Record 43 of Set 29 | chama
# Processing Record 44 of Set 29 | andradas
# Processing Record 45 of Set 29 | galdar
# Processing Record 46 of Set 29 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 29 | mpika
# Processing Record 48 of Set 29 | ishigaki
# Processing Record 49 of Set 29 | santo antonio do ica
# Processing Record 50 of Set 29 | khasan
# Processing Record 1 of Set 30 | atambua
# Processing Record 2 of Set 30 | sur
# Processing Record 3 of Set 30 | sao felix do xingu
# Processing Record 4 of Set 30 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 30 | sikeston
# Processing Record 6 of Set 30 | cam ranh
# Processing Record 7 of Set 30 | cardston
# Processing Record 8 of Set 30 | green valley
# Processing Record 9 of Set 30 | olenino
# Processing Record 10 of Set 30 | khombole
# Processing Record 11 of Set 30 | manta
# Processing Record 12 of Set 30 | minab
# Processing Record 13 of Set 30 | vallentuna
# Processing Record 14 of Set 30 | herran
# Processing Record 15 of Set 30 | mali
# Processing Record 16 of Set 30 | rosario
# Processing Record 17 of Set 30 | malchin
# Processing Record 18 of Set 30 | pakwach
# City not found. Skipping...
# Processing Record 19 of Set 30 | eldorado
# Processing Record 20 of Set 30 | venado tuerto
# Processing Record 21 of Set 30 | north vanlaiphai
# Processing Record 22 of Set 30 | newport
# Processing Record 23 of Set 30 | chiang khong
# Processing Record 24 of Set 30 | porto novo
# Processing Record 25 of Set 30 | ridgecrest
# Processing Record 26 of Set 30 | luba
# Processing Record 27 of Set 30 | indian head
# Processing Record 28 of Set 30 | killin
# Processing Record 29 of Set 30 | koslan
# Processing Record 30 of Set 30 | amuntai
# Processing Record 31 of Set 30 | itainopolis
# Processing Record 32 of Set 30 | lavumisa
# Processing Record 33 of Set 30 | klaeng
# Processing Record 34 of Set 30 | san juan
# Processing Record 35 of Set 30 | sapulpa
# Processing Record 36 of Set 30 | waitati
# Processing Record 37 of Set 30 | talaya
# Processing Record 38 of Set 30 | changli
# Processing Record 39 of Set 30 | xuddur
# Processing Record 40 of Set 30 | grande riviere du nord
# Processing Record 41 of Set 30 | nsanje
# Processing Record 42 of Set 30 | tiznit
# Processing Record 43 of Set 30 | rasskazovo
# Processing Record 44 of Set 30 | vanderhoof
# Processing Record 45 of Set 30 | sassandra
# Processing Record 46 of Set 30 | elesbao veloso
# Processing Record 47 of Set 30 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 30 | paragominas
# Processing Record 49 of Set 30 | abdanan
# Processing Record 50 of Set 30 | verkhovazhye
# Processing Record 1 of Set 31 | powell river
# Processing Record 2 of Set 31 | topchikha
# Processing Record 3 of Set 31 | giddalur
# Processing Record 4 of Set 31 | jibuti
# Processing Record 5 of Set 31 | mamallapuram
# Processing Record 6 of Set 31 | hastings
# Processing Record 7 of Set 31 | myaundzha
# Processing Record 8 of Set 31 | taybad
# Processing Record 9 of Set 31 | lamesa
# Processing Record 10 of Set 31 | tamayo
# Processing Record 11 of Set 31 | ola
# Processing Record 12 of Set 31 | stokmarknes
# Processing Record 13 of Set 31 | jadu
# Processing Record 14 of Set 31 | martinsburg
# Processing Record 15 of Set 31 | vrangel
# Processing Record 16 of Set 31 | los chiles
# Processing Record 17 of Set 31 | denpasar
# Processing Record 18 of Set 31 | katha
# City not found. Skipping...
# Processing Record 19 of Set 31 | saeby
# Processing Record 20 of Set 31 | anaconda
# Processing Record 21 of Set 31 | lasem
# Processing Record 22 of Set 31 | dzhebariki-khaya
# Processing Record 23 of Set 31 | treinta y tres
# Processing Record 24 of Set 31 | merauke
# Processing Record 25 of Set 31 | aranos
# Processing Record 26 of Set 31 | isla vista
# Processing Record 27 of Set 31 | makinsk
# Processing Record 28 of Set 31 | nagua
# Processing Record 29 of Set 31 | horizontina
# Processing Record 30 of Set 31 | port macquarie
# Processing Record 31 of Set 31 | kaduy
# Processing Record 32 of Set 31 | praia da vitoria
# Processing Record 33 of Set 31 | palafrugell
# Processing Record 34 of Set 31 | orneta
# Processing Record 35 of Set 31 | kunda
# Processing Record 36 of Set 31 | hanzhong
# Processing Record 37 of Set 31 | kulu
# Processing Record 38 of Set 31 | sendhwa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_data_df= pd.DataFrame(city_data)

# %%
WeatherPy_database= "weather_data/cities.csv"

weather_data_df.to_csv(WeatherPy_database, index_label="City_ID")
